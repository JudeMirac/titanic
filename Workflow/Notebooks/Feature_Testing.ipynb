# %%
# Load libraries
import pandas as pd # data manipulation
from pathlib import Path # located directory

# %%
# upload dataset with engineered features

# locate the directory
dir = Path.cwd()

# point to the data file 
data_path = dir.parent / 'Data' / 'uncut_feat.csv'

# load data 
df1 = pd.read_csv(data_path)

# %%
# before traing let's view which features are important in predicitng the target variable 

# Download ppscore 
# !pip install ppscore

# import ppscore
import ppscore as pps

# convert target variable to object type 
df1['Survived'] = df1['Survived'].astype(str)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ppscore in c:\users\dmiracju\appdata\roaming\python\python313\site-packages (1.3.1)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\dmiracju\appdata\roaming\python\python313\site-packages (from ppscore) (2.3.3)
# Requirement already satisfied: scikit-learn<2.0.0,>=0.20.2 in c:\users\dmiracju\appdata\roaming\python\python313\site-packages (from ppscore) (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\dmiracju\appdata\roaming\python\python313\site-packages (from scikit-learn<2.0.0,>=0.20.2->ppscore) (2.3.5)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\dmiracju\appdata\roaming\python\python313\site-packages (from scikit-learn<2.0.0,>=0.20.2->ppscore) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dmiracju\appdata\roaming\python\python313\site-packages (from scikit-learn<2.0.0,>=0.20.2->ppscore) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dmiracju\appdata\roaming\python\python313\site-packages (from scikit-learn<2.0.0,>=0.20.2->ppscore) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dmiracju\appdata\roaming\python\python313\site-packages (from pandas>=1.0.0->ppscore) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dmiracju\appdata\roaming\python\python313\site-packages (from pandas>=1.0.0->ppscore) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dmiracju\appdata\roaming\python\python313\site-packages (from pandas>=1.0.0->ppscore) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dmiracju\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ppscore) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# calculate PPS for the engineered feature
interaction1 = pps.score(df1, 'interaction1', 'Survived')
# Calculate PPS for individual variables 
score_sibsp = pps.score(df1, 'SibSp', 'Survived') 
score_parch = pps.score(df1, 'Parch', 'Survived')
# print results 
score_sibsp, score_parch, interaction1

# if the score is higher than the interaction feature, then it must be removed due to iniformational dilution
# (In otherwords, combining the variables togther may have weakend the predicitive power of the other leading to nosie creation)
# Out:
# ({'x': 'SibSp',
#   'y': 'Survived',
#   'ppscore': np.float64(0.15283725977852178),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.6082704276416958),
#   'model': DecisionTreeClassifier()},
#  {'x': 'Parch',
#   'y': 'Survived',
#   'ppscore': np.float64(0.06614237489730132),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.5681825571915692),
#   'model': DecisionTreeClassifier()},
#  {'x': 'interaction1',
#   'y': 'Survived',
#   'ppscore': np.float64(0.057029536548524856),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.563968764374851),
#   'model': DecisionTreeClassifier()})

# %%
# calculate PPS for engineered features
interaction2 = pps.score(df1, 'interaction2', 'Survived')

# calculate PPS for individually features (Note: no need to implement variables already calculated upstream!
score_fare = pps.score(df1, 'Fare', 'Survived') 

# Print results 
score_fare, score_sibsp, interaction2
# Out:
# ({'x': 'Fare',
#   'y': 'Survived',
#   'ppscore': np.float64(0.2885846293438929),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.6710402550950436),
#   'model': DecisionTreeClassifier()},
#  {'x': 'SibSp',
#   'y': 'Survived',
#   'ppscore': np.float64(0.15283725977852178),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.6082704276416958),
#   'model': DecisionTreeClassifier()},
#  {'x': 'interaction2',
#   'y': 'Survived',
#   'ppscore': np.float64(0.13176141685680234),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.5985249200280612),
#   'model': DecisionTreeClassifier()})

# %%
# calculate PPS for engineered features
interaction3 = pps.score(df1, 'interaction3', 'Survived')

# Calculate individual features (Note: no need to implement variables already calculated upstream!
# scores already calculate.. move to result phase 

# print results 
score_parch, score_fare, interaction3
# Out:
# ({'x': 'Parch',
#   'y': 'Survived',
#   'ppscore': np.float64(0.06614237489730132),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.5681825571915692),
#   'model': DecisionTreeClassifier()},
#  {'x': 'Fare',
#   'y': 'Survived',
#   'ppscore': np.float64(0.2885846293438929),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.6710402550950436),
#   'model': DecisionTreeClassifier()},
#  {'x': 'interaction3',
#   'y': 'Survived',
#   'ppscore': np.float64(0.08955700919559735),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.5790095261375826),
#   'model': DecisionTreeClassifier()})

# %%
# calculate pps for engineered features
interaction4 = pps.score(df1, 'interaction4', 'Survived')

# calculate pps for individual features (Note: no need to implement variables already calculated upstream!
score_age = pps.score(df1, 'Age', 'Survived')

# print results
score_age, score_fare, interaction4
# Out:
# ({'x': 'Age',
#   'y': 'Survived',
#   'ppscore': np.float64(0.07414415475609934),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.5718825945673546),
#   'model': DecisionTreeClassifier()},
#  {'x': 'Fare',
#   'y': 'Survived',
#   'ppscore': np.float64(0.2885846293438929),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.6710402550950436),
#   'model': DecisionTreeClassifier()},
#  {'x': 'interaction4',
#   'y': 'Survived',
#   'ppscore': np.float64(0.11521477845189809),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.5908737247162537),
#   'model': DecisionTreeClassifier()})

# %%
# Calculate pps for create features
interaction5 = pps.score(df1, 'interaction5', 'Survived')

# Calculate for individual variables (Note: no need to implement variables already calculated upstream!
score_pclass = pps.score(df1, 'Pclass', 'Survived')

# Print results 
score_pclass, score_fare, interaction5
# Out:
# ({'x': 'Pclass',
#   'y': 'Survived',
#   'ppscore': np.float64(0.24262382767496324),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.6497878978699044),
#   'model': DecisionTreeClassifier()},
#  {'x': 'Fare',
#   'y': 'Survived',
#   'ppscore': np.float64(0.2885846293438929),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.6710402550950436),
#   'model': DecisionTreeClassifier()},
#  {'x': 'interaction5',
#   'y': 'Survived',
#   'ppscore': np.float64(0.29612298753333655),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.674526005458737),
#   'model': DecisionTreeClassifier()})

# %%
# calculate pps score for engineered features
interaction6 = pps.score(df1, 'interaction6', 'Survived')

# calculate pps for individual variable (Note: no need to implement variables already calculated upstream!)
score_female = pps.score(df1, 'Sex_female', 'Survived')

# print results
score_female, score_fare, interaction6
# Out:
# ({'x': 'Sex_female',
#   'y': 'Survived',
#   'ppscore': np.float64(0.534659658932353),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.7848257906623226),
#   'model': DecisionTreeClassifier()},
#  {'x': 'Fare',
#   'y': 'Survived',
#   'ppscore': np.float64(0.2885846293438929),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.6710402550950436),
#   'model': DecisionTreeClassifier()},
#  {'x': 'interaction6',
#   'y': 'Survived',
#   'ppscore': np.float64(0.5499800705302618),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.7919099764965969),
#   'model': DecisionTreeClassifier()})

# %%
# calculate pps for engineered features
interaction7 = pps.score(df1, 'interaction7', 'Survived')

# calculate pps for indiviual columns
score_male = pps.score(df1, 'Sex_male', 'Survived')

# print results
score_male, score_fare, interaction7
# Out:
# ({'x': 'Sex_male',
#   'y': 'Survived',
#   'ppscore': np.float64(0.534659658932353),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.7848257906623226),
#   'model': DecisionTreeClassifier()},
#  {'x': 'Fare',
#   'y': 'Survived',
#   'ppscore': np.float64(0.2885846293438929),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.6710402550950436),
#   'model': DecisionTreeClassifier()},
#  {'x': 'interaction7',
#   'y': 'Survived',
#   'ppscore': np.float64(0.5538574824595344),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.7937028987354974),
#   'model': DecisionTreeClassifier()})

# %%
# Calculate pps score for engineered features
Ratio1 = pps.score(df1, 'Ratio1', 'Survived')

# print comparisons 
score_age, score_fare, Ratio1
# Out:
# ({'x': 'Age',
#   'y': 'Survived',
#   'ppscore': np.float64(0.07414415475609934),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.5718825945673546),
#   'model': DecisionTreeClassifier()},
#  {'x': 'Fare',
#   'y': 'Survived',
#   'ppscore': np.float64(0.2885846293438929),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.6710402550950436),
#   'model': DecisionTreeClassifier()},
#  {'x': 'Ratio1',
#   'y': 'Survived',
#   'ppscore': np.float64(0.10039035020949574),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.5840188824762202),
#   'model': DecisionTreeClassifier()})

# %%
# calculate pps for engineered features
Ratio2 = pps.score(df1, 'Ratio2', 'Survived')

# print comparison results 
score_sibsp, score_fare, Ratio2
# Out:
# ({'x': 'SibSp',
#   'y': 'Survived',
#   'ppscore': np.float64(0.15283725977852178),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.6082704276416958),
#   'model': DecisionTreeClassifier()},
#  {'x': 'Fare',
#   'y': 'Survived',
#   'ppscore': np.float64(0.2885846293438929),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.6710402550950436),
#   'model': DecisionTreeClassifier()},
#  {'x': 'Ratio2',
#   'y': 'Survived',
#   'ppscore': np.float64(0.13544736350383837),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.6002293083766346),
#   'model': DecisionTreeClassifier()})

# %%
# calculate pps for engineered features
Ratio3 = pps.score(df1, 'Ratio3', 'Survived')

# print comparison results
score_parch, score_fare, Ratio3
# Out:
# ({'x': 'Parch',
#   'y': 'Survived',
#   'ppscore': np.float64(0.06614237489730132),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.5681825571915692),
#   'model': DecisionTreeClassifier()},
#  {'x': 'Fare',
#   'y': 'Survived',
#   'ppscore': np.float64(0.2885846293438929),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.6710402550950436),
#   'model': DecisionTreeClassifier()},
#  {'x': 'Ratio3',
#   'y': 'Survived',
#   'ppscore': np.float64(0.12441831532299452),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.5951294566925631),
#   'model': DecisionTreeClassifier()})

# %%
# Calculate pps for engineered features
Ratio4 = pps.score(df1, 'Ratio4', 'Survived')

# print comparisons
score_female, score_fare, Ratio4
# Out:
# ({'x': 'Sex_female',
#   'y': 'Survived',
#   'ppscore': np.float64(0.534659658932353),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.7848257906623226),
#   'model': DecisionTreeClassifier()},
#  {'x': 'Fare',
#   'y': 'Survived',
#   'ppscore': np.float64(0.2885846293438929),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.6710402550950436),
#   'model': DecisionTreeClassifier()},
#  {'x': 'Ratio4',
#   'y': 'Survived',
#   'ppscore': np.float64(0.5534462923411001),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.7935127636863448),
#   'model': DecisionTreeClassifier()})

# %%
# calculate pps for engineered features
Ratio5 = pps.score(df1, 'Ratio5', 'Survived')

# print comparisons 
score_male, score_fare, Ratio5
# Out:
# ({'x': 'Sex_male',
#   'y': 'Survived',
#   'ppscore': np.float64(0.534659658932353),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.7848257906623226),
#   'model': DecisionTreeClassifier()},
#  {'x': 'Fare',
#   'y': 'Survived',
#   'ppscore': np.float64(0.2885846293438929),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.6710402550950436),
#   'model': DecisionTreeClassifier()},
#  {'x': 'Ratio5',
#   'y': 'Survived',
#   'ppscore': np.float64(0.5538574824595344),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.7937028987354974),
#   'model': DecisionTreeClassifier()})

# %%
# calculate other variables within the dataset and view thier predictive power 
Cabin_score = pps.score(df1, 'Cabin_encoded', 'Survived')
emarked_644_score = pps.score(df1, 'Embarked_644', 'Survived')
embarked_C_score = pps.score(df1, 'Embarked_C', 'Survived')
embarked_Q_score = pps.score(df1, 'Embarked_Q', "Survived")
embarked_S_score = pps.score(df1, 'Embarked_S', "Survived")

# results
Cabin_score, emarked_644_score, embarked_Q_score, embarked_S_score
# Out:
# ({'x': 'Cabin_encoded',
#   'y': 'Survived',
#   'ppscore': np.float64(0.27996129253130114),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.6670528086676724),
#   'model': DecisionTreeClassifier()},
#  {'x': 'Embarked_644',
#   'y': 'Survived',
#   'ppscore': 0,
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.47492590174930743),
#   'model': DecisionTreeClassifier()},
#  {'x': 'Embarked_Q',
#   'y': 'Survived',
#   'ppscore': 0,
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.4698262856315817),
#   'model': DecisionTreeClassifier()},
#  {'x': 'Embarked_S',
#   'y': 'Survived',
#   'ppscore': np.float64(0.14299796674466897),
#   'case': 'classification',
#   'is_valid_score': True,
#   'metric': 'weighted F1',
#   'baseline_score': np.float64(0.5375982042648709),
#   'model_score': np.float64(0.6037207208740781),
#   'model': DecisionTreeClassifier()})

# %%
# drop the features that reduce the scores of the individual powers
df2 = df1.drop(columns = ['interaction1', 'interaction2', 'interaction3', 'Ratio2', 'Ratio3'])

# save the new feature set to csv
df2.to_csv('Dominant_feat.csv', index = False)
